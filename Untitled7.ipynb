# %% [markdown]
# <a href="https://colab.research.google.com/github/sakethd11/ExcelRAD/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import atexit
import shutil
from transformers import BlenderbotTokenizer, BlenderbotForConditionalGeneration
model_name = "facebook/blenderbot-1B-distill"
tokenizer = BlenderbotTokenizer.from_pretrained(model_name)
model = BlenderbotForConditionalGeneration.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/127k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/62.9k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/16.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/310k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.87G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.87G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]

# %%
def interact_with_chatbot(user_input, conversation_history):
    conversation_history.append(f"User: {user_input}")
    conversation_text = " ".join(conversation_history[-5:])
    inputs = tokenizer(conversation_text, return_tensors="pt", truncation=True)
    response_ids = model.generate(**inputs, max_length=1000, pad_token_id=tokenizer.eos_token_id)
    response_text = tokenizer.decode(response_ids[0], skip_special_tokens=True)
    conversation_history.append(f"Chatbot: {response_text}")
    return response_text

# %%
def delete_model_files():
    cache_dir = os.path.expanduser("~/.cache/huggingface/hub/models--facebook--blenderbot-1B-distill")
    if os.path.exists(cache_dir):
        user_input = input("Do you want to delete the model files from the cache directory? (y/n): ")
        if user_input.lower() == 'y':
            shutil.rmtree(cache_dir)
            print(f"Deleted model files from cache directory: {cache_dir}")
        else:
            print("Model files not deleted from cache directory.")
    else:
        print(f"Model files not found in cache directory: {cache_dir}")

# %%
atexit.register(delete_model_files)
# Out:
# <function __main__.delete_model_files()>

# %%
print("Welcome to the Indian Tourism Chatbot!")
print("Type 'quit' to end the conversation.\n")
# Out:
# Welcome to the Indian Tourism Chatbot!
# Type 'quit' to end the conversation.

# %%
conversation_history = []
while True:
    user_input = input("User: ")
    if user_input.lower() == 'quit':
        print("Thank you for using the Indian Tourism Chatbot. Goodbye!")
        break
    response = interact_with_chatbot(user_input, conversation_history)
    print(f"Chatbot: {response}")
# Out:
# User: hello how are you?
# Chatbot:  Hello, I am doing well. How are you this evening? Do you have any plans?
# User: no
# Chatbot:  I'm doing well, thank you. I do not have plans either. How about you?
# User: NO
# Chatbot:  I'm good, thanks for asking. What do you like to do in your spare time?
# User: Movies
# Chatbot:  Movies are fun. I like to go to the movies with my friends. What kind of movies are you into?
# User: ok go with your friends then
# Chatbot:  I like action and comedy movies. Do you have a favorite movie that you want to see?
# User: Action
# Chatbot:  I love action movies. My favorite movie of all time is The Godfather Part II. Have you seen it?
# User:
# Chatbot:  No, I haven't seen that one. I'll have to check it out sometime.
# User: bye
# Chatbot:  Goodbye. I hope you have a good rest of your day. Have a good one.
# User: ok
# Chatbot:  You too! Thanks for chatting with me! Have a great day! Bye bye!
# User: ok.
# Chatbot:  Hi, how are you today? I am having a good day so far. Bye!
# User: end the chat
# Chatbot:  Good evening! I'm doing well. I hope you have a great rest of your day!
